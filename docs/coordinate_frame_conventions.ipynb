# %% [markdown]
# # Coordinate Frame Conventions — ENU, NED, FRD, FLU, RDF, RUB
#
# Every robotics stack, every flight controller, every camera library and every
# visualizer picks its own answer to the same three questions: *which way is X,
# which way is Y, which way is Z?* None of them is wrong — but the moment data
# crosses from one tool to another without being converted, you get the classic
# symptoms:
#
# * gravity points **up**,
# * the drone flies **underground** in RViz,
# * the map comes out **mirrored**,
# * yaw increases when the robot turns the *other* way.
#
# The good news: every convention on this page is **right-handed**, so no
# convention change ever needs a reflection — only a rotation that permutes and
# flips axes. Six small constant matrices, derived once below and verified in
# code, cover everything.
#
# ## How to read a frame name
#
# A frame name like **FLU** is just three letters naming where the **+X, +Y, +Z**
# axes point, in that order:
#
# | Name | +X | +Y | +Z | Typical owner |
# |---|---|---|---|---|
# | **ENU** | East | North | Up | ROS world frame (REP-103), mapping |
# | **NED** | North | East | Down | Aerospace, IMU datasheets, PX4 world |
# | **FLU** | Forward | Left | Up | ROS body frame `base_link` |
# | **FRD** | Forward | Right | Down | PX4 / aerospace body frame |
# | **RDF** | Right | Down | Forward | OpenCV camera, ROS `*_optical` frames |
# | **RUB** | Right | Up | Back | OpenGL camera (looks along −Z) |
#
# **Right-handed check:** point the fingers of your right hand along +X, curl
# them toward +Y — your thumb must point along +Z. Equivalently
# $\hat{x} \times \hat{y} = \hat{z}$. Try it on each row: East × North = Up ✓,
# North × East = Down ✓, Forward × Left = Up ✓, Forward × Right = Down ✓,
# Right × Down = Forward ✓, Right × Up = Back ✓. All six pass — they are the
# *same* handedness with different labels, which is exactly why pure rotations
# suffice to convert between them.

# %%
import numpy as np

np.set_printoptions(precision=3, suppress=True)

def cross_check(name, x, y, z):
    ok = np.allclose(np.cross(x, y), z)
    print(f"{name}:  x-hat x y-hat == z-hat ?  {ok}")
    assert ok

# Express each frame's axes in ENU components (E, N, U) just to test handedness.
E, N, U = np.eye(3)
cross_check("ENU", E, N, U)
cross_check("NED", N, E, -U)
# For body/camera frames pick an arbitrary heading: forward=N, left=-E, etc.
cross_check("FLU", N, -E, U)
cross_check("FRD", N, E, -U)
cross_check("RDF", E, -U, N)     # right=E, down=-U, forward=N
cross_check("RUB", E, U, -N)     # right=E, up=U,   back=-N
# Out:
# ENU:  x-hat x y-hat == z-hat ?  True
# NED:  x-hat x y-hat == z-hat ?  True
# FLU:  x-hat x y-hat == z-hat ?  True
# FRD:  x-hat x y-hat == z-hat ?  True
# RDF:  x-hat x y-hat == z-hat ?  True
# RUB:  x-hat x y-hat == z-hat ?  True

# %% [markdown]
# ---
#
# ## World frames: ENU and NED
#
# A **world frame** (also *local tangent frame*) is pinned to a point on the
# ground — usually where the robot booted — and does not move. Both ENU and NED
# align two axes with the local East/North directions and one with gravity; they
# differ only in the order and in which way the vertical axis points.
#
# ### ENU — East, North, Up
#
# * X → East, Y → North, Z → **Up**
# * Gravity vector: $\mathbf{g}_{\text{enu}} = (0,\, 0,\, -9.81)\ \text{m/s}^2$ — gravity is *negative* Z
# * Yaw is measured from **East**, counter-clockwise when seen from above
#   (the usual mathematical angle in the XY plane)
# * Used by: **ROS** (REP-103 world frame), Gazebo, most ground-robot mapping
#
# Intuitive for ground robots: altitude increases upward, the map lies in the XY
# plane like a sheet of paper on a table.
#
# ### NED — North, East, Down
#
# * X → North, Y → East, Z → **Down**
# * Gravity vector: $\mathbf{g}_{\text{ned}} = (0,\, 0,\, +9.81)\ \text{m/s}^2$ — gravity is *positive* Z
# * Yaw measured from **North**, clockwise seen from above — which makes
#   **yaw = compass heading** (0° North, 90° East). This is *the* reason
#   aerospace loves NED.
# * Used by: aerospace, marine, IMU/GNSS datasheets, **PX4 / ArduPilot** internally
#
# Down-positive feels odd until you remember that for an aircraft everything
# interesting (the ground) is below, and depth/altitude-loss being positive makes
# the flight-dynamics equations cleaner.
#
# <img src="images/frame_heading.px4.png" width="70%" />

# %% [markdown]
# ---
#
# ## Body frames: FLU and FRD
#
# A **body frame** is bolted to the robot and moves with it. Its origin is on the
# vehicle (center of mass, base footprint, IMU…), and "forward" means *the
# vehicle's* forward, wherever it is currently pointing.
#
# Roll, pitch, yaw are rotations about the body X, Y, Z axes respectively —
# which is why the *sign* of a roll or pitch depends on the body convention you
# picked.
#
# ### FLU — Forward, Left, Up (ROS `base_link`)
#
# * X → forward, Y → **left**, Z → up
# * REP-103's body-frame choice; pairs naturally with the ENU world
# * Positive yaw turns the robot **left** (counter-clockwise from above) —
#   consistent with the mathematical angle convention of ENU
#
# <img src="images/RPY_angles_of_cars.png" width="70%" />
#
# ### FRD — Forward, Right, Down (PX4 body)
#
# * X → forward, Y → **right**, Z → down
# * The aerospace body convention; pairs naturally with the NED world
# * Positive yaw turns the vehicle **right** (clockwise from above), positive
#   pitch is nose-up about the right wing, positive roll drops the right wing
#
# <img src="images/RPY_angles_of_airplanes.png" width="70%" />
#
# FLU and FRD share the forward axis and disagree on the other two — both Y and
# Z flip. Remember it as *"same nose, opposite belly."*

# %% [markdown]
# ---
#
# ## Camera frame: RDF (OpenCV / ROS optical)
#
# * X → right (increasing image **columns** $u$)
# * Y → down (increasing image **rows** $v$)
# * Z → forward, out of the lens (positive **depth**)
#
# This is the pinhole-camera convention used by OpenCV, and by ROS in every
# frame whose name ends in `_optical` (REP-103 defines both: `camera_link` is
# FLU like any body frame, `camera_link_optical` is RDF).
#
# It exists because of how images are stored: pixel $(u,v)$ counts columns
# rightward and rows **downward** from the top-left corner, and projection
# $u = f_x X/Z + c_x$, $v = f_y Y/Z + c_y$ only comes out sign-free if X is
# right, Y is down and Z is depth.
#
# It is also the single biggest source of frame bugs in robotics, because
# **nothing about it matches a body frame**: the camera's "forward" is Z where a
# robot's is X, and its Y points at the floor. Any pipeline that fuses camera
# output with an IMU, a planner or a SLAM backend must convert — explicitly —
# and the matrices for that are derived below.
#
# <img src="images/opencv_coordinate.png" width="70%" />

# %% [markdown]
# ---
#
# ## Graphics frame: RUB (OpenGL)
#
# * X → right, Y → up, Z → **back** — the camera looks along **−Z**
# * Right-handed, like everything else on this page
# * Used by OpenGL's eye/view space and inherited (with variations) by many
#   engines; Vulkan and Direct3D differ in details (depth range, Y flip)
#
# "Z backward" sounds absurd until you see the design goal: keep X right and Y
# up *on the screen* — matching 2-D screen coordinates — and then a right-handed
# Z has nowhere left to go but out of the screen toward the viewer. What you are
# looking at therefore sits at negative Z, which is why view matrices are full
# of minus signs.
#
# One nuance worth knowing: after the projection matrix, OpenGL's *clip space*
# (x, y, z each in [−1, 1]) is effectively **left-handed** — the projection flips
# Z so that larger depth values mean farther away. That flip lives inside the
# projection matrix and never leaks into your world- or view-space math.
#
# <img src="images/opengl_coordinate.png" width="70%" />

# %% [markdown]
# ---
#
# ## Visualization software
#
# ### RViz
#
# RViz *is* ROS: the fixed frame is ENU-style (Z up, grid in the XY plane) and
# robot models are FLU. There is no RViz-specific conversion — and that is a
# diagnostic tool in itself: **if your robot renders sideways or upside-down in
# RViz, your TF tree is wrong, not RViz.**
#
# ### Rerun
#
# Rerun does not hard-code a world convention — you *declare* one per entity
# tree with `rr.ViewCoordinates`, e.g.
#
# ```python
# rr.log("/world", rr.ViewCoordinates.RIGHT_HAND_Z_UP, static=True)
# ```
#
# and you can (and should) tag camera entities as RDF so pinhole frustums render
# correctly. Throughout these notes we use the common **RFU** choice for the
# Rerun world: X → right, Y → forward, Z → up. Note that is *not* the ROS
# convention — the conversion is derived below.
#
# <img src="images/rerun_coordinates.png" width="65%" />
# <img src="images/rerun_RDF_opencv_coordinate.png" width="65%" />
#
# ### Comparison table
#
# | System | X | Y | Z | Forward | Up |
# |---|---|---|---|---|---|
# | RViz / ROS world | East | North | Up | +X (body) | +Z |
# | ROS `base_link` | Forward | Left | Up | +X | +Z |
# | Gazebo world/body | Forward*/East | Left/North | Up | +X | +Z |
# | Rerun (as configured here) | Right | Forward | Up | +Y | +Z |
# | OpenCV / `*_optical` | Right | Down | Forward | +Z | −Y |
# | OpenGL view space | Right | Up | Back | −Z | +Y |
#
# \*Gazebo (classic and modern) uses the same ENU/FLU pair as ROS, so
# **Gazebo → ROS needs no conversion** — you only have to keep model, link and
# sensor frames self-consistent.
#
# ### "When I move the robot forward in code, do I change x, y, or z?"
#
# Change the axis your **current frame** calls forward. In a ROS or Gazebo body
# frame that is +X; in our Rerun world it is +Y; for an OpenCV camera it is +Z;
# in OpenGL it is −Z. There is no universal "forward" — only the frame's
# definition of it.

# %% [markdown]
# ---
#
# ## Converting vectors between conventions
#
# ### The recipe (derive one matrix, get the method for all of them)
#
# A physical vector $\mathbf{v}$ — a position, a velocity, a gravity vector —
# does not care about axes; only its *numbers* do. If frame $B$'s axes, written
# in $A$'s coordinates, are $\hat{x}_B, \hat{y}_B, \hat{z}_B$, then the numbers
# of $\mathbf{v}$ in $B$ are just its projections onto those axes:
#
# $$
# \mathbf{v}_B =
# \begin{bmatrix} \hat{x}_B^\top \\ \hat{y}_B^\top \\ \hat{z}_B^\top \end{bmatrix}
# \mathbf{v}_A
# \;=\; R_{B\leftarrow A}\, \mathbf{v}_A .
# $$
#
# So: **each row of $R_{B\leftarrow A}$ is one axis of the target frame,
# expressed in the source frame.** For convention changes every axis of the
# target is ± one axis of the source, so each row is a signed unit row and the
# matrix is a signed permutation. Being orthogonal, its inverse is its
# transpose: $R_{A\leftarrow B} = R_{B\leftarrow A}^\top$. And because both
# frames are right-handed, $\det R = +1$ — a genuine rotation, checked in code
# below.
#
# ### Worked example: NED → ENU, row by row
#
# * ENU's first axis is **East**. In NED, East is the **second** axis → row 1 is $(0, 1, 0)$.
# * ENU's second axis is **North**. In NED, North is the **first** axis → row 2 is $(1, 0, 0)$.
# * ENU's third axis is **Up**. In NED, Up is **minus** the third axis → row 3 is $(0, 0, -1)$.
#
# $$
# R_{\text{enu}\leftarrow\text{ned}} =
# \begin{bmatrix} 0 & 1 & 0 \\ 1 & 0 & 0 \\ 0 & 0 & -1 \end{bmatrix}
# \qquad\Longleftrightarrow\qquad
# \begin{aligned}
# x_{\text{enu}} &= y_{\text{ned}} \\
# y_{\text{enu}} &= x_{\text{ned}} \\
# z_{\text{enu}} &= -z_{\text{ned}}
# \end{aligned}
# $$
#
# This matrix happens to be its own inverse (swap X/Y, flip Z — doing it twice
# undoes it), so the same matrix converts ENU → NED.
#
# ### The rest, by the same recipe
#
# **FRD → FLU** (and back — also its own inverse): forward stays, left = −right,
# up = −down:
#
# $$
# R_{\text{flu}\leftarrow\text{frd}} =
# \begin{bmatrix} 1 & 0 & 0 \\ 0 & -1 & 0 \\ 0 & 0 & -1 \end{bmatrix}
# $$
#
# **OpenCV RDF → ROS FLU** (a camera point into body-style axes): forward = cv's
# Z, left = −(cv's right) = −X, up = −(cv's down) = −Y:
#
# $$
# R_{\text{flu}\leftarrow\text{cv}} =
# \begin{bmatrix} 0 & 0 & 1 \\ -1 & 0 & 0 \\ 0 & -1 & 0 \end{bmatrix}
# $$
#
# **OpenCV RDF → Rerun RFU**: right stays, forward = cv's Z, up = −(cv's down):
#
# $$
# R_{\text{rfu}\leftarrow\text{cv}} =
# \begin{bmatrix} 1 & 0 & 0 \\ 0 & 0 & 1 \\ 0 & -1 & 0 \end{bmatrix}
# $$
#
# **ROS FLU → Rerun RFU**: right = −left = −Y, forward = X, up stays:
#
# $$
# R_{\text{rfu}\leftarrow\text{ros}} =
# \begin{bmatrix} 0 & -1 & 0 \\ 1 & 0 & 0 \\ 0 & 0 & 1 \end{bmatrix}
# $$
#
# **Gazebo → ROS**: identity. Same conventions.

# %%
# Every conversion matrix on this page, verified.
R = {}
R["enu<-ned"] = np.array([[0, 1, 0], [1, 0, 0], [0, 0, -1]], float)
R["flu<-frd"] = np.diag([1.0, -1.0, -1.0])
R["flu<-cv"]  = np.array([[0, 0, 1], [-1, 0, 0], [0, -1, 0]], float)
R["rfu<-cv"]  = np.array([[1, 0, 0], [0, 0, 1], [0, -1, 0]], float)
R["rfu<-ros"] = np.array([[0, -1, 0], [1, 0, 0], [0, 0, 1]], float)

for name, M in R.items():
    assert np.allclose(M @ M.T, np.eye(3)), name        # orthogonal
    assert np.isclose(np.linalg.det(M), 1.0), name      # proper rotation
    print(f"{name}:  orthogonal, det = {np.linalg.det(M):+.0f}")

# Gravity: down is down in every convention.
g_ned = np.array([0, 0, 9.81])
print("\ngravity NED", g_ned, " -> ENU", R["enu<-ned"] @ g_ned)
assert np.allclose(R["enu<-ned"] @ g_ned, [0, 0, -9.81])

# A drone 10 m north, 5 m east, 20 m above home, in both world conventions.
p_ned = np.array([10, 5, -20.0])          # 20 m up = -20 down
p_enu = R["enu<-ned"] @ p_ned
print("position NED", p_ned, " -> ENU", p_enu)
assert np.allclose(p_enu, [5, 10, 20])

# A camera point: 2 m ahead of the lens, 0.5 m to its right, 0.3 m below axis.
p_cv = np.array([0.5, 0.3, 2.0])          # RDF: right, down, forward
p_flu = R["flu<-cv"] @ p_cv
print("camera pt RDF", p_cv, " -> FLU", p_flu, " (ahead, half a metre right -> y=-0.5, below axis -> z=-0.3)")
assert np.allclose(p_flu, [2.0, -0.5, -0.3])

# Round trip is exact: the inverse is the transpose.
assert np.allclose(R["flu<-cv"].T @ p_flu, p_cv)
print("round trip cv -> flu -> cv exact")
# Out:
# enu<-ned:  orthogonal, det = +1
# flu<-frd:  orthogonal, det = +1
# flu<-cv:  orthogonal, det = +1
# rfu<-cv:  orthogonal, det = +1
# rfu<-ros:  orthogonal, det = +1
#
# gravity NED [0.   0.   9.81]  -> ENU [ 0.    0.   -9.81]
# position NED [ 10.   5. -20.]  -> ENU [ 5. 10. 20.]
# camera pt RDF [0.5 0.3 2. ]  -> FLU [ 2.  -0.5 -0.3]  (ahead, half a metre right -> y=-0.5, below axis -> z=-0.3)
# round trip cv -> flu -> cv exact

# %% [markdown]
# ---
#
# ## Converting rotations and poses — the part everyone gets wrong
#
# Converting a *vector* needs one matrix. Converting a *rotation* (an attitude,
# a camera pose) generally needs **two**, and using one is the classic silent
# bug.
#
# ### Derivation
#
# Say PX4 hands you an attitude $R_{\text{old}}$, meaning: it maps body
# coordinates to world coordinates, body convention FRD, world convention NED,
#
# $$ \mathbf{v}_{\text{ned}} = R_{\text{old}}\, \mathbf{v}_{\text{frd}} . $$
#
# You want the same physical attitude as ROS expects it, FLU body to ENU world.
# Insert the two convention changes — nothing else:
#
# $$
# \mathbf{v}_{\text{enu}}
# = \underbrace{R_{\text{enu}\leftarrow\text{ned}}}_{C_w}\, \mathbf{v}_{\text{ned}}
# = C_w\, R_{\text{old}}\, \mathbf{v}_{\text{frd}}
# = C_w\, R_{\text{old}}\, \underbrace{R_{\text{frd}\leftarrow\text{flu}}}_{C_b^\top}\, \mathbf{v}_{\text{flu}}
# $$
#
# $$
# \boxed{\; R_{\text{new}} \;=\; C_w \, R_{\text{old}} \, C_b^\top \;}
# \qquad
# C_w = R_{\text{enu}\leftarrow\text{ned}},\quad C_b = R_{\text{flu}\leftarrow\text{frd}} .
# $$
#
# **Left matrix relabels the world side; right matrix relabels the body side.**
# A full pose $(R, \mathbf{t})$ converts as
# $R_{\text{new}} = C_w R_{\text{old}} C_b^\top$ and
# $\mathbf{t}_{\text{new}} = C_w \mathbf{t}_{\text{old}}$ — the translation is an
# ordinary world-frame vector, so it only needs the world-side matrix.
#
# ### When is one-sided ($R' = C_w R$) actually correct?
#
# Only when you deliberately keep the body/child frame in its old convention and
# relabel the world side alone. The standard example is a camera in ROS: you
# publish the pose of `camera_link_optical` — which *stays* RDF by definition —
# in an ENU-style world. Then multiplying by $C_w$ on the left is the whole job.
# If instead you want the pose of an FLU `camera_link`, the right-hand $C_b^\top$
# must be there too. Deciding *which of the two you are doing* — and writing the
# frame names down — is the entire game.
#
# ### Sanity check you can do in your head: yaw
#
# NED yaw is measured from North, clockwise; ENU yaw from East,
# counter-clockwise. Both describe the same nose direction, so they must satisfy
#
# $$ \psi_{\text{enu}} = 90^\circ - \psi_{\text{ned}} \pmod{360^\circ}. $$
#
# A drone heading East is $\psi_{\text{ned}} = 90^\circ$ and
# $\psi_{\text{enu}} = 0^\circ$. The code below builds the attitude from NED/FRD
# yaw, converts it two-sided, and recovers exactly that relation.

# %%
def Rz(a):
    c, s = np.cos(a), np.sin(a)
    return np.array([[c, -s, 0], [s, c, 0], [0, 0, 1]])

C_w = R["enu<-ned"]
C_b = R["flu<-frd"]

for yaw_ned_deg in [0, 45, 90, 180, 270]:
    R_old = Rz(np.radians(yaw_ned_deg))              # NED<-FRD attitude, pure yaw
    R_new = C_w @ R_old @ C_b.T                      # ENU<-FLU, two-sided
    yaw_enu = np.degrees(np.arctan2(R_new[1, 0], R_new[0, 0]))
    print(f"yaw NED {yaw_ned_deg:3d} deg  ->  yaw ENU {yaw_enu:6.1f} deg   (90 - ned = {(90 - yaw_ned_deg + 180) % 360 - 180:6.1f})")
    assert np.isclose((yaw_enu - (90 - yaw_ned_deg)) % 360, 0, atol=1e-9)

# A positive check first: 20 deg nose-up (FRD pitch is +nose-up), heading
# East. The ENU forward direction must come out climbing (z > 0).
def Ry(a):
    c, s = np.cos(a), np.sin(a)
    return np.array([[c, 0, s], [0, 1, 0], [-s, 0, c]])

yaw = np.radians(90)                                  # NED: nose East
nose = (C_w @ Rz(yaw) @ Ry(np.radians(20)) @ C_b.T) @ np.array([1, 0, 0])
print("\nnose-up 20 deg, heading East -> ENU nose direction:", nose, " (z > 0, climbing)")
assert nose[2] > 0

# The one-sided trap, made visible. FLU and FRD SHARE the forward axis, so
# asking "where does the nose point?" can never expose a missing C_b -- the
# subtle bugs never can be seen on the axis the conventions agree about.
# Ask about the ROOF instead: FLU up is [0,0,1], but fed into a matrix whose
# body side is still FRD, that same column means DOWN.
R_two = C_w @ Rz(yaw) @ C_b.T          # ENU<-FLU, correct
R_one = C_w @ Rz(yaw)                  # forgot the body-side matrix
roof_two = R_two @ np.array([0, 0, 1])
roof_one = R_one @ np.array([0, 0, 1])
print("roof in ENU, two-sided:", roof_two, " -> up. Correct.")
print("roof in ENU, one-sided:", roof_one, " -> the robot renders UPSIDE-DOWN.")
assert roof_two[2] > 0 and roof_one[2] < 0
# Out:
# yaw NED   0 deg  ->  yaw ENU   90.0 deg   (90 - ned =   90.0)
# yaw NED  45 deg  ->  yaw ENU   45.0 deg   (90 - ned =   45.0)
# yaw NED  90 deg  ->  yaw ENU    0.0 deg   (90 - ned =    0.0)
# yaw NED 180 deg  ->  yaw ENU  -90.0 deg   (90 - ned =  -90.0)
# yaw NED 270 deg  ->  yaw ENU -180.0 deg   (90 - ned = -180.0)
#
# nose-up 20 deg, heading East -> ENU nose direction: [0.94  0.    0.342]  (z > 0, climbing)
# roof in ENU, two-sided: [0. 0. 1.]  -> up. Correct.
# roof in ENU, one-sided: [ 0.  0. -1.]  -> the robot renders UPSIDE-DOWN.

# %% [markdown]
# ---
#
# ## Putting it together: the canonical pipeline
#
# **Convert at the boundaries, never inside the math.** Pick one world
# convention for your system (in ROS land: ENU/FLU), convert every input into it
# once, on arrival, and every output out of it once, on the way to the
# visualizer.
#
# ```
# PX4 (NED world, FRD body)      OpenCV (RDF camera)
#         │  C_w = R_enu<-ned            │  R_flu<-cv
#         │  C_b = R_flu<-frd            │
#         ▼                              ▼
#             ROS  (ENU world, FLU body)          ← all fusion, SLAM,
#         │                                          planning happens here
#         │  R_rfu<-ros
#         ▼
#             Rerun (RFU world)  /  RViz (no conversion)
# ```
#
# The corresponding code pattern:
#
# ```python
# # 1. Express motion in the body frame
# v_body = [v_forward, 0, 0]
#
# # 2. Body -> world (the robot's attitude does this)
# v_world = R_world_body @ v_body
#
# # 3. World -> visualization convention, once, at the very end
# p_vis = R_vis_world @ p_world
# R_vis = R_vis_world @ R_world_body        # one-sided: keeps the body labels
# ```
#
# Going PX4 → Rerun? Go **through** the ROS convention rather than deriving a
# direct matrix. The direct product is trivial to compute — but every extra
# hand-derived matrix is another chance for a sign error, and the staged path
# lets you sanity-check gravity and yaw at each hop.
#
# ## Sanity checks (run them every time)
#
# 1. **Gravity points down** in the frame you are in ($-Z$ in ENU/FLU-world
#    displays, $+Z$ in NED).
# 2. **Forward motion increases the forward axis** — command the robot forward a
#    metre and watch which coordinate grows.
# 3. **Positive yaw spins about the up-axis** the way the convention says
#    (counter-clockwise in ENU, clockwise-from-above in NED).
# 4. $\det R = +1$ and $R R^\top = I$ for every conversion matrix you write down.
# 5. "It looks right in the visualizer" is **not** a test — a mirrored
#    trajectory looks fine until it doesn't. Check numbers, not vibes.
#
# ## Takeaway
#
# * A frame name is three letters: where +X, +Y, +Z point. ENU, NED, FLU, FRD,
#   RDF, RUB — all right-handed.
# * **Vectors** convert with one signed-permutation matrix; each *row* is a
#   target axis written in source coordinates.
# * **Rotations and poses** convert with two: $R' = C_w R\, C_b^\top$ — world
#   labels on the left, body labels on the right. One-sided is a special case
#   you must *choose*, not a default.
# * Sensors never agree on frames, visualizers never agree on frames — the math
#   always agrees, as long as every quantity carries its frame names.
